# %% [markdown]
# # Primeros pasos

# %%
# Instalación de NumPy y Pandas
# !pip install numpy pandas matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 7.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 7.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 7.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 7.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 7.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# Importación de librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
In [1]: %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('./bandera-de-mexico.jpg')
print(img)
# Out:
# [[[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  ...
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]]

# %%
tensor = np.array([
    [[2, 88, 1],
     [2, 88, 1],
     [2, 88, 1],
     [165, 0, 14],
     [165, 0, 14],
     [165, 0, 14]],
    
    [[2, 88, 1],
     [2, 88, 1],
     [2, 88, 1],
     [165, 0, 14],
     [165, 0, 14],
     [165, 0, 14]],
    
    [[2, 88, 1],
     [2, 88, 1],
     [2, 88, 1],
     [165, 0, 14],
     [165, 0, 14],
     [165, 0, 14]]
])

# %%
plt.imshow(tensor, interpolation='nearest')
plt.axis('off')  # Opcional: quitar ejes para una mejor visualización
plt.show()

# %%
img = mpimg.imread('./bandera-de-mexico.jpg')
plt.imshow(img)
plt.show()

# %%
# Dimensiones de la imagen
alto = 360      # 360 píxeles de alto (360p)
ancho_franco = 180  # ancho de cada franja
ancho_total = 3 * ancho_franco  # 540 píxeles de ancho

# Colores en formato RGB
verde = [2, 88, 1]
blanco = [255, 255, 255]
rojo = [165, 0, 14]

# Creamos cada franja con la función np.full
franja_verde = np.full((alto, ancho_franco, 3), verde, dtype=np.uint8)
franja_blanca = np.full((alto, ancho_franco, 3), blanco, dtype=np.uint8)
franja_roja = np.full((alto, ancho_franco, 3), rojo, dtype=np.uint8)

# Unimos las franjas horizontalmente para formar el tensor de la bandera
bandera_tensor = np.hstack((franja_verde, franja_blanca, franja_roja))

# Visualizamos la bandera usando matplotlib
plt.imshow(bandera_tensor, interpolation='nearest')
plt.axis('off')  # Opcional: quita los ejes para una mejor visualización
plt.title("Bandera de México - Resolución 360p")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Polygon

# ========================
# 1. Construcción de la bandera
# ========================

# Dimensiones de la imagen (360 píxeles de alto, 540 píxeles de ancho)
alto = 360
ancho_franco = 180         # Cada franja tiene 1/3 del ancho total
ancho_total = 3 * ancho_franco  # 540 píxeles en total

# Definición de colores (RGB)
verde = [2, 88, 1]         # Franja verde
blanco = [255, 255, 255]   # Franja blanca
rojo = [165, 0, 14]        # Franja roja

# Crear cada franja con np.full usando el dtype apropiado para imágenes
franja_verde = np.full((alto, ancho_franco, 3), verde, dtype=np.uint8)
franja_blanca = np.full((alto, ancho_franco, 3), blanco, dtype=np.uint8)
franja_roja = np.full((alto, ancho_franco, 3), rojo, dtype=np.uint8)

# Combinar horizontalmente las tres franjas para formar el tensor de la bandera
bandera_tensor = np.hstack((franja_verde, franja_blanca, franja_roja))

# ========================
# 2. Dibujar la bandera y el escudo
# ========================

# Configurar la figura y ejes
fig, ax = plt.subplots(figsize=(6, 4))
ax.imshow(bandera_tensor, interpolation='nearest')
ax.axis('off')  # Quitar ejes

# Posición del escudo: se encuentra en la franja blanca, en el centro
# La franja blanca se extiende horizontalmente de x=180 a x=360
center_x = (180 + 360) / 2  # = 270 píxeles (centro horizontal)
center_y = alto / 2         # = 180 píxeles (centro vertical)

# ========================
# 3. Añadir un escudo simplificado con vectores
# ========================

# (a) Dibujar un óvalo que sirva de contenedor/forma base para el escudo.
# Se escoge un óvalo (Ellipse) con dimensiones representativas.
escudo_width = 80  # ancho del escudo (en píxeles)
escudo_height = 100  # altura del escudo (en píxeles)
escudo = Ellipse(xy=(center_x, center_y), width=escudo_width, height=escudo_height,
                 edgecolor='black', facecolor='gold', lw=2)
ax.add_patch(escudo)

# (b) Sobre el óvalo, agregamos un polígono simple para representar
# simbólicamente un elemento (por ejemplo, podría simbolizar un ave o parte del detalle).
# Se define un triángulo centrado en el área del escudo.
polygon_points = np.array([
    [center_x, center_y - 30],   # Punto superior
    [center_x - 10, center_y + 20],  # Punto inferior izquierdo
    [center_x + 10, center_y + 20]   # Punto inferior derecho
])
escudo_polygon = Polygon(polygon_points, closed=True, edgecolor='black',
                         facecolor='darkred', lw=2)
ax.add_patch(escudo_polygon)

# Título para la visualización
plt.title("Bandera de México - 360p con Escudo Simplificado")

# Mostrar la imagen final
plt.show()

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Cargar la imagen original
img = mpimg.imread('./bandera-de-mexico.jpg')
print("Dimensiones originales:", img.shape)
print("Tipo:", img.dtype)

# Convertir a uint8 si es necesario:
if img.dtype != np.uint8:
    img_uint8 = (img * 255).astype(np.uint8)
else:
    img_uint8 = img

# Convertir el array NumPy a imagen PIL
pil_img = Image.fromarray(img_uint8)

# Obtener dimensiones originales (PIL usa (ancho, alto))
ancho_original, alto_original = pil_img.size

# Definir nueva altura (360p) y calcular el nuevo ancho manteniendo la relación de aspecto
nuevo_alto = 360
nuevo_ancho = int(ancho_original * nuevo_alto / alto_original)

# Redimensionar la imagen utilizando el método de interpolación LANCZOS
pil_img_resized = pil_img.resize((nuevo_ancho, nuevo_alto), resample=Image.LANCZOS)

# Convertir la imagen PIL redimensionada en un array de NumPy (tensor)
img_resized = np.array(pil_img_resized)

# Visualizar la imagen escalada
plt.imshow(img_resized)
plt.axis('off')

plt.show()

# Imprimir las dimensiones del tensor resultante
print("Dimensiones de la imagen escalada:", img_resized.shape)
# Out:
# Dimensiones originales: (640, 1024, 3)
# Tipo: uint8
# Dimensiones de la imagen escalada: (360, 576, 3)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Abrir imagen
img_pil = Image.open('./bandera-de-mexico.jpg')

# Obtener tamaño original
original_size = img_pil.size  # (ancho, alto)

# Definir nueva altura
nuevo_alto = 360
nuevo_ancho = int(original_size[0] * nuevo_alto / original_size[1])

# Redimensionar
img_pil.thumbnail((nuevo_ancho, nuevo_alto), Image.LANCZOS)  # reemplaza ANTIALIAS por LANCZOS

# Convertir a tensor (numpy array)
tensor_360p = np.array(img_pil)

# Mostrar
plt.imshow(tensor_360p)
plt.axis('off')
plt.title("Escalado con thumbnail")
plt.show()

# Imprimir tensor
print("Dimensiones tensor 360p:", tensor_360p.shape)
# Out:
# Dimensiones tensor 360p: (360, 576, 3)

# %%
print(tensor_360p)
# Out:
# [[[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  ...
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]
#
#  [[  2  88   1]
#   [  2  88   1]
#   [  2  88   1]
#   ...
#   [165   0  14]
#   [165   0  14]
#   [165   0  14]]]

# %%
import numpy as np

# Asegúrate de que tensor_360p esté definido
np.savetxt("tensor_360p.txt", tensor_360p.reshape(-1, tensor_360p.shape[2]), fmt='%d')

# %%
# Guardar el array completo como archivo NumPy
np.save("tensor_360p.npy", tensor_360p)

# %%
import json

# Supongamos que tu tensor se llama `tensor_360p`
with open("tensor_360p.json", "w") as f:
    json.dump(tensor_360p.tolist(), f)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Abrir imagen
img_pil = Image.open('./bandera-de-mexico.jpg')

# Obtener tamaño original
original_size = img_pil.size  # (ancho, alto)

# Definir nueva altura
nuevo_alto = 32
nuevo_ancho = int(original_size[0] * nuevo_alto / original_size[1])

# Redimensionar
img_pil.thumbnail((nuevo_ancho, nuevo_alto), Image.LANCZOS)  # reemplaza ANTIALIAS por LANCZOS

# Convertir a tensor (numpy array)
tensor_32p = np.array(img_pil)

# Mostrar
plt.imshow(tensor_32p)
plt.axis('off')
plt.title("Escalado con thumbnail")
plt.show()

# Imprimir tensor
print("Dimensiones tensor 360p:", tensor_32p.shape)
# Out:
# Dimensiones tensor 360p: (32, 51, 3)

# %%
import json

# Supongamos que tu tensor se llama `tensor_360p`
with open("tensor_32p.json", "w") as f:
    json.dump(tensor_32p.tolist(), f)
